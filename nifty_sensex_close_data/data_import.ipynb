# %%
import yfinance as yf
import numpy as np
import pandas as pd

# %%
tcs_data = pd.DataFrame(yf.Ticker("TCS.NS").history(period="1mo"))
tcs_data
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2024-04-16 00:00:00+05:30  3873.844233  3900.351524  3834.976825  3844.854980
# 2024-04-18 00:00:00+05:30  3848.826068  3907.598848  3822.219401  3834.132812
# 2024-04-19 00:00:00+05:30  3810.305967  3824.751026  3773.473574  3798.591064
# 2024-04-22 00:00:00+05:30  3809.313169  3850.017323  3784.493563  3836.714111
# 2024-04-23 00:00:00+05:30  3849.074351  3866.894780  3832.743098  3846.741211
# 2024-04-24 00:00:00+05:30  3861.930835  3869.873109  3796.853777  3803.406250
# 2024-04-25 00:00:00+05:30  3783.699409  3845.698739  3783.500900  3824.403564
# 2024-04-26 00:00:00+05:30  3827.332036  3848.825960  3775.111731  3793.776123
# 2024-04-29 00:00:00+05:30  3810.306076  3849.818939  3791.641683  3842.273682
# 2024-04-30 00:00:00+05:30  3844.060623  3853.740269  3782.507999  3793.081055
# 2024-05-02 00:00:00+05:30  3750.788724  3843.167350  3750.788724  3835.423584
# ...

# %%
tcs_data.reset_index(inplace=True)
tcs_data.rename(columns={"index": "Date"}, inplace=True)

# %%
tcs_data = tcs_data.drop(columns=['Volume','Dividends','Stock Splits'])
tcs_data
# Out:
#                         Date         Open         High          Low  \
# 0  2024-04-16 00:00:00+05:30  3873.844233  3900.351524  3834.976825
# 1  2024-04-18 00:00:00+05:30  3848.826068  3907.598848  3822.219401
# 2  2024-04-19 00:00:00+05:30  3810.305967  3824.751026  3773.473574
# 3  2024-04-22 00:00:00+05:30  3809.313169  3850.017323  3784.493563
# 4  2024-04-23 00:00:00+05:30  3849.074351  3866.894780  3832.743098
# 5  2024-04-24 00:00:00+05:30  3861.930835  3869.873109  3796.853777
# 6  2024-04-25 00:00:00+05:30  3783.699409  3845.698739  3783.500900
# 7  2024-04-26 00:00:00+05:30  3827.332036  3848.825960  3775.111731
# 8  2024-04-29 00:00:00+05:30  3810.306076  3849.818939  3791.641683
# 9  2024-04-30 00:00:00+05:30  3844.060623  3853.740269  3782.507999
# 10 2024-05-02 00:00:00+05:30  3750.788724  3843.167350  3750.788724
# 11 2024-05-03 00:00:00+05:30  3862.079657  3865.504957  3770.197666
# 12 2024-05-06 00:00:00+05:30  3825.197817  3911.520362  3825.197817
# ...

# %%
ticker_list =np.array(['M&M.NS','MARUTI.NS','NESTLEIND.NS','NTPC.NS','POWERGRID.NS','RELIANCE.NS','SBIN.NS','SUNPHARMA.NS','TATAMOTORS.NS','TATASTEEL.NS','TCS.NS','TECHM.NS','TITAN.NS','ULTRACEMCO.NS','WIPRO.NS','ASIANPAINT.NS','AXISBANK.NS','BAJFINANCE.NS','BAJAJFINSV.NS','BHARTIARTL.NS','HCLTECH.NS','HDFCBANK.NS','HINDUNILVR.NS','ICICIBANK.NS','INDUSINDBK.NS','INFY.NS','ITC.NS','JSWSTEEL.NS','KOTAKBANK.NS','LT.NS'])

# %%
trial = pd.DataFrame(yf.Ticker("TCS.NS").history(start="2011-01-01",
                                     end="2023-12-31"))
trial
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2011-01-03 00:00:00+05:30   449.801575   453.636626   445.002940   446.351959
# 2011-01-04 00:00:00+05:30   448.606626   449.473852   438.662410   441.225555
# 2011-01-05 00:00:00+05:30   441.418333   449.377556   440.069314   446.698761
# 2011-01-06 00:00:00+05:30   450.187041   455.583119   444.444064   451.613129
# 2011-01-07 00:00:00+05:30   453.270540   457.452491   438.681867   440.416321
# ...                                ...          ...          ...          ...
# 2023-12-22 00:00:00+05:30  3755.179803  3800.587785  3717.628005  3778.896729
# 2023-12-26 00:00:00+05:30  3774.795661  3788.778668  3745.445774  3750.782227
# 2023-12-27 00:00:00+05:30  3754.191504  3773.164995  3723.557143  3766.247559
# 2023-12-28 00:00:00+05:30  3778.896652  3792.731525  3747.373003  3755.080811
# 2023-12-29 00:00:00+05:30  3747.274324  3777.513501  3720.987968  3748.657715
#
# ...

# %%
n = 3204

# %%
trial.reset_index(inplace=True)
trial.rename(columns={"index": "Date"}, inplace=True)

# %%
sensex_df = pd.DataFrame()
sensex_df['Date'] = trial['Date'].dt.date
sensex_df
# Out:
#             Date
# 0     2011-01-03
# 1     2011-01-04
# 2     2011-01-05
# 3     2011-01-06
# 4     2011-01-07
# ...          ...
# 3199  2023-12-22
# 3200  2023-12-26
# 3201  2023-12-27
# 3202  2023-12-28
# 3203  2023-12-29
#
# [3204 rows x 1 columns]

# %%
sensex_df['Date'].dtype
# Out:
# dtype('O')

# %%
for x in ticker_list:
    d = pd.DataFrame(yf.Ticker(x).history(start="2011-01-01",
                                     end="2023-12-31"))
    l = []
    for i in range(n):
        para = []
        for j in range(4):
            para.append(str(d.iloc[i,j]))
        s = "/".join(para)
        l.append(s)
    
    sensex_df[x] = l

sensex_df
# Out:
#             Date                                             M&M.NS  \
# 0     2011-01-03  357.8624659280758/360.99193872661425/353.11198...
# 1     2011-01-04  354.4177444559813/356.6241421875/349.059393152...
# 2     2011-01-05  351.7836273992247/355.27332098302503/344.55659...
# 3     2011-01-06  349.8699196987059/350.3202027356412/341.314541...
# 4     2011-01-07  344.10628806969225/344.8717746973949/329.62967...
# ...          ...                                                ...
# 3199  2023-12-22                      1630.0/1652.0/1622.75/1634.25
# 3200  2023-12-26           1640.9000244140625/1669.0/1634.5/1662.25
# 3201  2023-12-27  1670.0/1691.800048828125/1660.25/1687.94995117...
# 3202  2023-12-28  1688.949951171875/1739.949951171875/1688.40002...
# 3203  2023-12-29            1730.0/1758.0/1715.0/1729.4000244140625
#
#                                               MARUTI.NS  \
# 0     1294.186623378024/1312.2871355931013/1283.7788...
# ...

# %%
sensex_df.to_csv('Sensex_2011_to_2023.csv')
