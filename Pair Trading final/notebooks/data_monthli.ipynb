# %%
import numpy as np
import pandas as pd
import sys

# %%
data=pd.read_csv('/Users/vedantgupta/Documents/summer project/data-analysis-with-technical-indicators-2/Pair Trading final/data/Nifty_50_close.csv')

# %%
data
# Out:
#             Date  ADANIENT.NS  ADANIPORTS.NS  APOLLOHOSP.NS  ASIANPAINT.NS  \
# 0     2011-01-03    83.153633     134.706543     439.091125     259.076141
# 1     2011-01-04    83.358696     137.957016     435.507385     255.619690
# 2     2011-01-05    83.576599     146.361649     430.650635     259.612366
# 3     2011-01-06    82.596054     143.900589     427.349915     256.818451
# 4     2011-01-07    80.506813     136.749664     432.772583     250.171555
# ...          ...          ...            ...            ...            ...
# 3199  2023-12-22  2808.350098    1027.500000    5536.405762    3341.300049
# 3200  2023-12-26  2865.449951    1028.750000    5628.072754    3383.350098
# 3201  2023-12-27  2843.350098    1024.400024    5682.324219    3404.449951
# 3202  2023-12-28  2809.899902    1016.950012    5755.308105    3397.250000
# 3203  2023-12-29  2848.949951    1024.349976    5698.958984    3402.399902
#
# ...

# %%
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)
weekly_data = data.resample('W').first()

weekly_data.reset_index(inplace=True)

weekly_data
# Out:
#           Date  ADANIENT.NS  ADANIPORTS.NS  APOLLOHOSP.NS  ASIANPAINT.NS  \
# 0   2011-01-09    83.153633     134.706543     439.091125     259.076141
# 1   2011-01-16    74.924774     130.388138     446.682709     241.339020
# 2   2011-01-23    78.103516     127.323494     440.269867     239.996140
# 3   2011-01-30    81.487343     132.106247     484.641113     236.219772
# 4   2011-02-06    72.316422     130.527466     463.705078     232.303726
# ..         ...          ...            ...            ...            ...
# 673 2023-12-03  2423.500000     837.700012    5361.962891    3148.350098
# 674 2023-12-10  2531.199951     878.650024    5617.482422    3194.550049
# 675 2023-12-17  2855.800049    1031.900024    5542.350586    3233.000000
# 676 2023-12-24  2980.600098    1094.300049    5493.693848    3332.050049
# 677 2023-12-31  2865.449951    1028.750000    5628.072754    3383.350098
#
#      AXISBANK.NS  BAJAJ-AUTO.NS  BAJFINANCE.NS  BAJAJFINSV.NS     BPCL.NS  \
# ...

# %%
weekly_data.to_csv('/Users/vedantgupta/Documents/summer project/data-analysis-with-technical-indicators-2/Pair Trading final/data/Nifty_50_close_weekly.csv', index=False)
