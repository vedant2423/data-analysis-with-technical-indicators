# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('/Users/hitengoel/Machine Learning/data analysis(technical indiactors)/data-analysis-with-technical-indicators/nifty_sensex_close_data/data/NIFTY_2011_to_2023.csv')
data
# Out:
#       Unnamed: 0        Date  \
# 0              0  2011-01-03
# 1              1  2011-01-04
# 2              2  2011-01-05
# 3              3  2011-01-06
# 4              4  2011-01-07
# ...          ...         ...
# 3199        3199  2023-12-22
# 3200        3200  2023-12-26
# 3201        3201  2023-12-27
# 3202        3202  2023-12-28
# 3203        3203  2023-12-29
#
#                                             ADANIENT.NS  \
# 0     83.95472830389801/84.56996695698675/82.6729747...
# 1     83.31383803109055/84.08288619352118/82.8395852...
# 2     82.67296427364644/84.56995626076863/82.2179408...
# 3     84.08929246206789/86.49257756038884/79.4813962...
# 4     82.8972810605397/84.08290036749405/79.87234501...
# ...                                                 ...
# 3199  2815.949951171875/2847.60009765625/2791.399902...
# 3200  2817.0/2893.75/2800.10009765625/2865.449951171875
# 3201  2880.699951171875/2894.800048828125/2833.60009...
# ...

# %%
data = data.drop(columns='Unnamed: 0')
data
# Out:
#             Date                                        ADANIENT.NS  \
# 0     2011-01-03  83.95472830389801/84.56996695698675/82.6729747...
# 1     2011-01-04  83.31383803109055/84.08288619352118/82.8395852...
# 2     2011-01-05  82.67296427364644/84.56995626076863/82.2179408...
# 3     2011-01-06  84.08929246206789/86.49257756038884/79.4813962...
# 4     2011-01-07  82.8972810605397/84.08290036749405/79.87234501...
# ...          ...                                                ...
# 3199  2023-12-22  2815.949951171875/2847.60009765625/2791.399902...
# 3200  2023-12-26  2817.0/2893.75/2800.10009765625/2865.449951171875
# 3201  2023-12-27  2880.699951171875/2894.800048828125/2833.60009...
# 3202  2023-12-28  2855.0/2867.35009765625/2800.10009765625/2809....
# 3203  2023-12-29  2823.89990234375/2863.300048828125/2802.850097...
#
#                                           ADANIPORTS.NS  \
# 0     135.17088816052737/135.96026648413448/132.8491...
# ...

# %%
print(data.dtypes)
# Out:
# Date             object
# ADANIENT.NS      object
# ADANIPORTS.NS    object
# APOLLOHOSP.NS    object
# ASIANPAINT.NS    object
# AXISBANK.NS      object
# BAJAJ-AUTO.NS    object
# BAJFINANCE.NS    object
# BAJAJFINSV.NS    object
# BPCL.NS          object
# BHARTIARTL.NS    object
# BRITANNIA.NS     object
# CIPLA.NS         object
# COALINDIA.NS     object
# DIVISLAB.NS      object
# DRREDDY.NS       object
# EICHERMOT.NS     object
# GRASIM.NS        object
# HCLTECH.NS       object
# HDFCBANK.NS      object
# HEROMOTOCO.NS    object
# HINDALCO.NS      object
# HINDUNILVR.NS    object
# ICICIBANK.NS     object
# ITC.NS           object
# INDUSINDBK.NS    object
# INFY.NS          object
# JSWSTEEL.NS      object
# KOTAKBANK.NS     object
# LT.NS            object
# M&M.NS           object
# MARUTI.NS        object
# NTPC.NS          object
# NESTLEIND.NS     object
# ONGC.NS          object
# POWERGRID.NS     object
# RELIANCE.NS      object
# SHRIRAMFIN.NS    object
# ...

# %%
for i in range(1,len(data.columns)):
    for j in range(len(data)):
        s = data.iloc[j,i].split('/')
        data.iloc[j,i] = s[-1]
    data[data.columns[i]] = data[data.columns[i]].astype(float)

print(data.dtypes)
# Out:
# Date              object
# ADANIENT.NS      float64
# ADANIPORTS.NS    float64
# APOLLOHOSP.NS    float64
# ASIANPAINT.NS    float64
# AXISBANK.NS      float64
# BAJAJ-AUTO.NS    float64
# BAJFINANCE.NS    float64
# BAJAJFINSV.NS    float64
# BPCL.NS          float64
# BHARTIARTL.NS    float64
# BRITANNIA.NS     float64
# CIPLA.NS         float64
# COALINDIA.NS     float64
# DIVISLAB.NS      float64
# DRREDDY.NS       float64
# EICHERMOT.NS     float64
# GRASIM.NS        float64
# HCLTECH.NS       float64
# HDFCBANK.NS      float64
# HEROMOTOCO.NS    float64
# HINDALCO.NS      float64
# HINDUNILVR.NS    float64
# ICICIBANK.NS     float64
# ITC.NS           float64
# INDUSINDBK.NS    float64
# INFY.NS          float64
# JSWSTEEL.NS      float64
# KOTAKBANK.NS     float64
# LT.NS            float64
# M&M.NS           float64
# MARUTI.NS        float64
# NTPC.NS          float64
# NESTLEIND.NS     float64
# ONGC.NS          float64
# POWERGRID.NS     float64
# RELIANCE.NS      float64
# ...

# %%
data['Date'] = pd.to_datetime(data['Date'])
print(data.dtypes)
# Out:
# Date             datetime64[ns]
# ADANIENT.NS             float64
# ADANIPORTS.NS           float64
# APOLLOHOSP.NS           float64
# ASIANPAINT.NS           float64
# AXISBANK.NS             float64
# BAJAJ-AUTO.NS           float64
# BAJFINANCE.NS           float64
# BAJAJFINSV.NS           float64
# BPCL.NS                 float64
# BHARTIARTL.NS           float64
# BRITANNIA.NS            float64
# CIPLA.NS                float64
# COALINDIA.NS            float64
# DIVISLAB.NS             float64
# DRREDDY.NS              float64
# EICHERMOT.NS            float64
# GRASIM.NS               float64
# HCLTECH.NS              float64
# HDFCBANK.NS             float64
# HEROMOTOCO.NS           float64
# HINDALCO.NS             float64
# HINDUNILVR.NS           float64
# ICICIBANK.NS            float64
# ITC.NS                  float64
# INDUSINDBK.NS           float64
# INFY.NS                 float64
# JSWSTEEL.NS             float64
# KOTAKBANK.NS            float64
# ...

# %%
data
# Out:
#            Date  ADANIENT.NS  ADANIPORTS.NS  APOLLOHOSP.NS  ASIANPAINT.NS  \
# 0    2011-01-03    83.153633     134.706543     439.091125     259.076141
# 1    2011-01-04    83.358696     137.957016     435.507385     255.619690
# 2    2011-01-05    83.576599     146.361649     430.650635     259.612366
# 3    2011-01-06    82.596054     143.900589     427.349915     256.818451
# 4    2011-01-07    80.506813     136.749664     432.772583     250.171555
# ...         ...          ...            ...            ...            ...
# 3199 2023-12-22  2808.350098    1027.500000    5536.405762    3341.300049
# 3200 2023-12-26  2865.449951    1028.750000    5628.072754    3383.350098
# 3201 2023-12-27  2843.350098    1024.400024    5682.324219    3404.449951
# 3202 2023-12-28  2809.899902    1016.950012    5755.308105    3397.250000
# 3203 2023-12-29  2848.949951    1024.349976    5698.958984    3402.399902
#
#       AXISBANK.NS  BAJAJ-AUTO.NS  BAJFINANCE.NS  BAJAJFINSV.NS     BPCL.NS  \
# ...

# %%
data.to_csv('/Users/hitengoel/Machine Learning/data analysis(technical indiactors)/data-analysis-with-technical-indicators/Pair Trading final/data/Nifty_50_close.csv',index=False)
