# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
groups = [['ADANIPORTS.NS', 'ASIANPAINT.NS', 'BPCL.NS', 'DIVISLAB.NS', 'GRASIM.NS', 'HCLTECH.NS', 'HDFCBANK.NS', 'NTPC.NS', 'POWERGRID.NS', 'SUNPHARMA.NS', 'TCS.NS', 'TITAN.NS'],
          ['BAJFINANCE.NS', 'BHARTIARTL.NS', 'CIPLA.NS', 'DRREDDY.NS', 'INDUSINDBK.NS', 'KOTAKBANK.NS', 'M&M.NS', 'RELIANCE.NS', 'SHRIRAMFIN.NS', 'WIPRO.NS'],
          ['APOLLOHOSP.NS', 'BAJAJ-AUTO.NS', 'BRITANNIA.NS', 'EICHERMOT.NS', 'HEROMOTOCO.NS', 'HINDUNILVR.NS', 'ITC.NS', 'NESTLEIND.NS', 'ULTRACEMCO.NS'],
          ['HINDALCO.NS', 'INFY.NS', 'JSWSTEEL.NS', 'LT.NS', 'MARUTI.NS', 'ONGC.NS', 'SBIN.NS', 'TATASTEEL.NS'],
          ['AXISBANK.NS', 'COALINDIA.NS', 'ICICIBANK.NS', 'TATACONSUM.NS', 'TATAMOTORS.NS', 'TECHM.NS']]

# %%
trading_window = 21

# %%
master_macd = pd.read_csv('/Users/hitengoel/Machine Learning/data analysis(technical indiactors)/data-analysis-with-technical-indicators/Pair Trading final/data/master_macd_nifty.csv')
master_macd = master_macd[14:]
master_macd = master_macd.reset_index(drop=True)
master_macd = master_macd[232:725]
master_macd
# Out:
#            Date  ADANIENT.NS  ADANIPORTS.NS  APOLLOHOSP.NS  ASIANPAINT.NS  \
# 232  2012-01-02            0             -1              0              0
# 233  2012-01-03            0              1              0              1
# 234  2012-01-04           -1              0              0              0
# 235  2012-01-05            0              0              1              0
# 236  2012-01-06            0              0              0              0
# ..          ...          ...            ...            ...            ...
# 720  2013-12-24            0             -1              0              0
# 721  2013-12-26            0              0              0              0
# 722  2013-12-27            0              0              0              0
# 723  2013-12-30            0              0              0              0
# 724  2013-12-31            0              0              0              0
#
#      AXISBANK.NS  BAJAJ-AUTO.NS  BAJFINANCE.NS  BAJAJFINSV.NS  BPCL.NS  ...  \
# ...

# %%
master_rsi = pd.read_csv('/Users/hitengoel/Machine Learning/data analysis(technical indiactors)/data-analysis-with-technical-indicators/Pair Trading final/data/master_rsi_values.csv')
master_rsi = master_rsi[232:725]
master_rsi
# Out:
#            Date  ADANIENT.NS  ADANIPORTS.NS  APOLLOHOSP.NS  ASIANPAINT.NS  \
# 232  2012-01-02    30.068511      34.553659      47.290838      31.167518
# 233  2012-01-03    29.687270      42.597232      48.230537      39.608116
# 234  2012-01-04    27.071222      45.860226      50.536682      42.387600
# 235  2012-01-05    24.301324      50.440721      51.214466      42.088331
# 236  2012-01-06    25.380258      51.586483      51.096672      41.022812
# ..          ...          ...            ...            ...            ...
# 720  2013-12-24    59.999813      52.373830      60.798492      39.621227
# 721  2013-12-26    60.653896      53.121996      63.656501      41.990848
# 722  2013-12-27    62.042227      53.182901      74.484365      38.810551
# 723  2013-12-30    57.026133      49.126199      76.021624      41.569776
# 724  2013-12-31    54.194976      46.968180      74.543812      43.707019
#
#      AXISBANK.NS  BAJAJ-AUTO.NS  BAJFINANCE.NS  BAJAJFINSV.NS    BPCL.NS  ...  \
# ...

# %%
prices = pd.read_csv('/Users/hitengoel/Machine Learning/data analysis(technical indiactors)/data-analysis-with-technical-indicators/Pair Trading final/data/Nifty_50_close.csv')
prices = prices[14:]
prices = prices.reset_index(drop=True)
prices = prices[232:725]
prices
# Out:
#            Date  ADANIENT.NS  ADANIPORTS.NS  APOLLOHOSP.NS  ASIANPAINT.NS  \
# 232  2012-01-02    37.360771     107.228615     525.169067     235.916962
# 233  2012-01-03    37.192516     112.463844     529.493469     241.563690
# 234  2012-01-04    36.001732     114.847740     539.994751     243.626602
# 235  2012-01-05    34.571499     118.446945     543.035950     243.330658
# 236  2012-01-06    34.759174     119.381821     542.560852     242.319687
# ..          ...          ...            ...            ...            ...
# 720  2013-12-24    37.932167     151.242538     841.483582     453.056488
# 721  2013-12-26    38.115818     151.859665     851.102295     455.333771
# 722  2013-12-27    38.497261     151.907120     903.090881     450.918518
# 723  2013-12-30    37.614292     149.106354     913.478943     453.474792
# 724  2013-12-31    37.084522     147.539810     910.304871     455.473328
#
#      AXISBANK.NS  BAJAJ-AUTO.NS  BAJFINANCE.NS  BAJAJFINSV.NS    BPCL.NS  ...  \
# ...

# %% [markdown]
# # Strat-1 fixed exit the end of the window

# %%
def get_returns(groups,master_macd,master_rsi,prices,period) :
    returns = []
    temp = 0
    intrade = []
    i = 0
    while i<len(prices):
        for group in groups:
            buy = 0
            buy_rsi = 100.0
            sell = 0
            sell_rsi = 0.0
            for j in range(1,len(prices.columns)):
                if(prices.columns[j] in group):
                    if(master_macd.iloc[i,j]==1):
                        if(master_rsi.iloc[i,j]<buy_rsi):
                            buy = j
                            buy_rsi = master_rsi.iloc[i,j]
                    elif(master_macd.iloc[i,j]==-1):
                        if(master_rsi.iloc[i,j]>sell_rsi):
                            sell = j
                            sell_rsi = master_rsi.iloc[i,j]
            
            if(buy!=0 and sell!=0):
                l = [i,buy,sell]
                intrade.append(l)
        
        if((i+1)%period==0):
            temp = 0
            for x in range(len(intrade)):
                b1 = prices.iloc[intrade[x][0],intrade[x][1]]
                s1 = prices.iloc[intrade[x][0],intrade[x][2]]
                b2 = prices.iloc[i,intrade[x][1]]
                s2 = prices.iloc[i,intrade[x][2]]
                temp += ((b2-b1)/b1) - ((s2-s1)/s2)
            intrade = []
            returns.append(temp)

        i += 1

    return returns

# %%
returns = get_returns(groups,master_macd,master_rsi,prices,trading_window)
returns
# Out:
# [0.16788333662335692,
#  0.003984528442587177,
#  -0.09852814166169717,
#  0.25740073681875364,
#  -0.32777633208282037,
#  -0.03544250511967503,
#  -0.2195297038440554,
#  0.15539797569521846,
#  0.46120651041823985,
#  -0.1357058424627885,
#  0.008470521351131688,
#  -0.027437600858774835,
#  0.03790588430218054,
#  0.12559385408560655,
#  0.061086010481954583,
#  -0.13935388891698977,
#  0.25777167126574296,
#  -0.08221187722908749,
#  -0.08191824456877753,
#  -0.17229073389642424,
#  0.053250330687756926,
#  0.19549337201566386,
#  0.041183744011534046]

# %%
returns = np.array(returns)
cumulative_wealth = (1+returns).cumprod() 
cumulative_wealth
# Out:
# array([1.16788334, 1.1725368 , 1.05700893, 1.32908381, 0.89344159,
#        0.86177578, 0.6725904 , 0.77710959, 1.13551759, 0.98142122,
#        0.98973437, 0.96257843, 0.99906582, 1.12454234, 1.19323615,
#        1.02695405, 1.29167371, 1.18548279, 1.08837012, 0.90085404,
#        0.94882481, 1.13431377, 1.18102906])

# %%
periods = []
for i in range(len(returns)):
    periods.append(i+1)

weeks = np.array(periods)
cumulative_returns = np.array(cumulative_wealth)

# %%
plt.plot(periods,cumulative_wealth)
plt.xlabel(f'{trading_window}-Day Periods')
plt.ylabel('Cumulative Wealth')
plt.title(f'Cumulative Wealth vs {trading_window}-Day Periods')
plt.show()

# %% [markdown]
# # Strat-2 with variable exit in window + fixed exit at the end

# %%
def get_returns_2(groups,master_macd,master_rsi,prices,period) :
    returns = []
    temp = 0
    intrade = []
    i = 0
    while i<len(prices):
        for group in groups:
            buy = 0
            buy_rsi = 100.0
            sell = 0
            sell_rsi = 0.0
            for j in range(1,len(prices.columns)):
                if(prices.columns[j] in group):
                    if(master_macd.iloc[i,j]==1):
                        if(master_rsi.iloc[i,j]<buy_rsi):
                            buy = j
                            buy_rsi = master_rsi.iloc[i,j]
                    elif(master_macd.iloc[i,j]==-1):
                        if(master_rsi.iloc[i,j]>sell_rsi):
                            sell = j
                            sell_rsi = master_rsi.iloc[i,j]
            
            if(buy!=0 and sell!=0):
                l = [i,buy,sell]
                intrade.append(l)
            elif(buy!=0):
                for trade in intrade:
                    if(trade[2]==buy):
                        b1 = prices.iloc[trade[0],trade[1]]
                        s1 = prices.iloc[trade[0],trade[2]]
                        b2 = prices.iloc[i,trade[1]]
                        s2 = prices.iloc[i,trade[2]]
                        temp += ((b2-b1)/b1) - ((s2-s1)/s2)
                        intrade.remove(trade)
            elif(sell!=0):
                for trade in intrade:
                    if(trade[1]==sell):
                        b1 = prices.iloc[trade[0],trade[1]]
                        s1 = prices.iloc[trade[0],trade[2]]
                        b2 = prices.iloc[i,trade[1]]
                        s2 = prices.iloc[i,trade[2]]
                        temp += ((b2-b1)/b1) - ((s2-s1)/s2)
                        intrade.remove(trade)
        
        if((i+1)%period==0):
            temp = 0
            for x in range(len(intrade)):
                b1 = prices.iloc[intrade[x][0],intrade[x][1]]
                s1 = prices.iloc[intrade[x][0],intrade[x][2]]
                b2 = prices.iloc[i,intrade[x][1]]
                s2 = prices.iloc[i,intrade[x][2]]
                temp += ((b2-b1)/b1) - ((s2-s1)/s2)
            intrade = []
            returns.append(temp)

        i += 1

    return returns

# %%
returns = get_returns_2(groups,master_macd,master_rsi,prices,trading_window)
returns
# Out:
# [0.16389662174200803,
#  0.04869359486579584,
#  -0.027429997371424274,
#  0.23950444820913103,
#  -0.1295826401113554,
#  0,
#  -0.059322654719385214,
#  0.008643162654949545,
#  0.06381280655808472,
#  0.10061770861712489,
#  0.1305369640244808,
#  -0.03449062221763712,
#  0.04653339305885561,
#  0.1973945357723136,
#  0.0044710223961499235,
#  -0.0335823784246594,
#  0.3060047503238028,
#  0.01848879035640414,
#  0.05739007263130955,
#  0,
#  0.053250330687756926,
#  0.23578836828250438,
#  0.027400508289292393]

# %%
returns = np.array(returns)
cumulative_wealth = (1+returns).cumprod() 
cumulative_wealth
# Out:
# array([1.16389662, 1.22057093, 1.18709067, 1.47140417, 1.28073573,
#        1.28073573, 1.20475909, 1.21517202, 1.29271556, 1.42278563,
#        1.60851175, 1.55303318, 1.62530108, 1.94612664, 1.95482781,
#        1.88918004, 2.46727811, 2.5128951 , 2.65711033, 2.65711033,
#        2.79860234, 3.45848021, 3.55324433])

# %%
periods = []
for i in range(len(returns)):
    periods.append(i+1)

weeks = np.array(periods)
cumulative_returns = np.array(cumulative_wealth)

# %%
plt.plot(periods,cumulative_wealth)
plt.xlabel(f'{trading_window}-Day Periods')
plt.ylabel('Cumulative Wealth')
plt.title(f'Cumulative Wealth vs {trading_window}-Day Periods')
plt.show()
