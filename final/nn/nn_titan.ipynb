# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#for neural network
import tensorflow as tf
from tensorflow import keras
from keras import layers, models
from keras.models import Sequential, Model, load_model
from keras.layers import Reshape, Dense, Input
from sklearn.model_selection import train_test_split
import keras_tuner as kt

import sys
np.set_printoptions(threshold=sys.maxsize)

# %% [markdown]
# # Data

# %%
df=pd.read_csv('/Users/vedantgupta/Documents/summer project/data-analysis-with-technical-indicators-2/final/Data_imports/TITAN.NS(close).csv')
df.head
# Out:
# <bound method NDFrame.head of             Date  TITAN.NS(close)
# 0     2011-01-03       172.213837
# 1     2011-01-04       170.863907
# 2     2011-01-05       170.083847
# 3     2011-01-06       167.194824
# 4     2011-01-07       159.387192
# ...          ...              ...
# 3199  2023-12-22      3627.350098
# 3200  2023-12-26      3656.699951
# 3201  2023-12-27      3689.250000
# 3202  2023-12-28      3715.100098
# 3203  2023-12-29      3675.449951
#
# [3204 rows x 2 columns]>

# %%
def make_dataset(df,w):
    
    l=int(len(df))
    n=int(0.8*(l-w))

    #for close price
    df_close=df['TITAN.NS(close)']
    df_close = df_close.astype(float)
    data_i=np.zeros((l-w,w))

    for i in range (l-w):
        for j in range(w):
            data_i[i][j]=df_close[i+j]

    data_o=np.array([df_close[i+w] for i in range(l-w)])
    data_o=data_o.reshape(l-w,1)

    data=np.column_stack((data_i,data_o))

    #training and validating data
    tv_data=data[:n,:]
    np.random.seed(0)
    np.random.shuffle(tv_data)

    #test data
    test_data=data[n:,:-1]
    act_data=data[n:,-1]
    
    return tv_data,test_data,act_data

# %%
def split_dataset(ran_tv_close):
    
    X_close=ran_tv_close[:,:-1]
    y_close=ran_tv_close[:,-1]
    X_train_close, X_val_close, y_train_close, y_val_close = train_test_split(X_close, y_close, test_size=0.2, random_state=0)

    return X_train_close, X_val_close, y_train_close, y_val_close

# %%
tv_data,test_data,act_data=make_dataset(df,124)
X_train_close, X_val_close, y_train_close, y_val_close=split_dataset(tv_data)

X_train_close.shape, X_val_close.shape, y_train_close.shape, y_val_close.shape, test_data.shape, act_data.shape
# Out:
# ((1971, 124), (493, 124), (1971,), (493,), (616, 124), (616,))

# %% [markdown]
# # Model

# %%
initalizer2 = keras.initializers.HeNormal

tf.keras.backend.clear_session()

# %%
w=124
def model_builder(hp):
  model = keras.Sequential()
  act = hp.Choice('activation', values=['relu','sigmoid', 'tanh'])
  hp_units = hp.Int('units', min_value=32, max_value=512, step=32)
  hl = hp.Int('layers', min_value=2, max_value=6, step=1)
  model.add(Dense(hp_units, input_shape=(w,), activation=act, name = 'Input'))
  for i in range(hl):
    model.add(Dense(units=hp_units, activation=act))
  model.add(Dense(1))
  hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
  model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate), loss='mse',metrics=['mape'] )
  return model

# %%
tuner = kt.Hyperband(model_builder, objective=kt.Objective("val_mape", direction="min"), max_epochs=10, factor=3, directory='titan124', project_name='intro_to_kt')
# Out:
# Reloading Tuner from titan124/intro_to_kt/tuner0.json

# %%
with tf.device('/CPU:0'):
    tuner.search(X_train_close,y_train_close, epochs=100, batch_size=25, validation_data=(X_val_close,y_val_close))
    best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]
    model=tuner.hypermodel.build(best_hps)
    print(model.summary())

    history=model.fit(X_train_close, y_train_close, epochs=100, batch_size=25, validation_data=(X_val_close,y_val_close))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Input (Dense)                   │ (None, 416)            │        52,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 416)            │       173,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 416)            │       173,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 416)            │       173,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 416)            │       173,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 416)            │       173,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 416)            │       173,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │           417 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,093,249 (4.17 MB)
#  Trainable params: 1,093,249 (4.17 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 66779.9219 - mape: 23.9512 - val_loss: 2929.4106 - val_mape: 6.1192
# Epoch 2/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2767.2283 - mape: 5.7792 - val_loss: 1583.9977 - val_mape: 4.4221
# Epoch 3/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1965.1543 - mape: 4.9687 - val_loss: 1180.6576 - val_mape: 3.7727
# Epoch 4/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1160.5398 - mape: 4.0750 - val_loss: 1338.8459 - val_mape: 4.1146
# Epoch 5/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1381.2523 - mape: 4.3281 - val_loss: 870.5040 - val_mape: 3.3136
# Epoch 6/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1230.2301 - mape: 3.8283 - val_loss: 980.3482 - val_mape: 3.5194
# Epoch 7/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1775.7935 - mape: 4.6466 - val_loss: 1586.6820 - val_mape: 4.6190
# Epoch 8/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1046.8431 - mape: 3.5374 - val_loss: 692.6738 - val_mape: 3.0835
# Epoch 9/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 800.4116 - mape: 3.1611 - val_loss: 697.8131 - val_mape: 2.9945
# Epoch 10/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1082.0643 - mape: 3.6962 - val_loss: 615.3519 - val_mape: 2.8149
# Epoch 11/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 713.9480 - mape: 2.8818 - val_loss: 562.8412 - val_mape: 2.7468
# Epoch 12/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 694.2176 - mape: 2.8833 - val_loss: 525.9629 - val_mape: 2.6270
# Epoch 13/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 779.0897 - mape: 3.1808 - val_loss: 805.6673 - val_mape: 3.0626
# Epoch 14/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1032.2922 - mape: 3.6356 - val_loss: 883.0927 - val_mape: 3.5928
# Epoch 15/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 760.6771 - mape: 3.0142 - val_loss: 483.0410 - val_mape: 2.5946
# Epoch 16/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 817.9551 - mape: 3.2038 - val_loss: 589.4428 - val_mape: 2.7684
# Epoch 17/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 614.1916 - mape: 2.6623 - val_loss: 634.2692 - val_mape: 2.8988
# Epoch 18/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 666.0673 - mape: 2.8825 - val_loss: 565.5142 - val_mape: 2.7679
# Epoch 19/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2305.8037 - mape: 5.5653 - val_loss: 928.5411 - val_mape: 3.5874
# Epoch 20/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 914.0042 - mape: 3.3513 - val_loss: 478.4460 - val_mape: 2.5211
# Epoch 21/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 632.9924 - mape: 2.9177 - val_loss: 1640.3047 - val_mape: 5.1649
# Epoch 22/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 848.4235 - mape: 3.3343 - val_loss: 715.9987 - val_mape: 3.0556
# Epoch 23/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 594.3266 - mape: 2.8376 - val_loss: 462.4161 - val_mape: 2.4183
# Epoch 24/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 511.4240 - mape: 2.5850 - val_loss: 559.1901 - val_mape: 2.7062
# Epoch 25/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 546.0115 - mape: 2.5467 - val_loss: 528.7207 - val_mape: 2.7360
# Epoch 26/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 555.1470 - mape: 2.6787 - val_loss: 901.1041 - val_mape: 3.4805
# Epoch 27/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 522.5118 - mape: 2.6812 - val_loss: 469.4077 - val_mape: 2.4474
# Epoch 28/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 478.1653 - mape: 2.6024 - val_loss: 407.0858 - val_mape: 2.3758
# Epoch 29/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 803.1570 - mape: 2.9173 - val_loss: 515.4240 - val_mape: 2.7188
# Epoch 30/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 552.3066 - mape: 2.6233 - val_loss: 817.4386 - val_mape: 3.3922
# Epoch 31/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 929.4446 - mape: 3.3223 - val_loss: 731.3122 - val_mape: 3.0720
# Epoch 32/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 559.4835 - mape: 2.7703 - val_loss: 687.1501 - val_mape: 2.9992
# Epoch 33/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 527.7715 - mape: 2.6816 - val_loss: 395.5617 - val_mape: 2.2837
# Epoch 34/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 681.1498 - mape: 2.9408 - val_loss: 1010.1988 - val_mape: 3.6347
# Epoch 35/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 824.1724 - mape: 3.2593 - val_loss: 381.0334 - val_mape: 2.3510
# Epoch 36/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 574.6856 - mape: 2.7061 - val_loss: 525.0416 - val_mape: 2.7179
# Epoch 37/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 785.0388 - mape: 3.1266 - val_loss: 432.9946 - val_mape: 2.4316
# Epoch 38/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 551.6344 - mape: 2.6405 - val_loss: 476.0943 - val_mape: 2.5672
# Epoch 39/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 758.9286 - mape: 3.1711 - val_loss: 444.6450 - val_mape: 2.4006
# Epoch 40/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 621.4197 - mape: 2.8014 - val_loss: 865.0178 - val_mape: 3.7298
# Epoch 41/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 661.9366 - mape: 3.0594 - val_loss: 401.1820 - val_mape: 2.3042
# Epoch 42/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 411.8263 - mape: 2.4211 - val_loss: 662.5772 - val_mape: 2.8894
# Epoch 43/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 452.3195 - mape: 2.4284 - val_loss: 351.1848 - val_mape: 2.2233
# Epoch 44/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 638.5099 - mape: 2.7957 - val_loss: 381.2953 - val_mape: 2.3095
# Epoch 45/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 606.0633 - mape: 2.5946 - val_loss: 826.8375 - val_mape: 3.3865
# Epoch 46/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 677.5825 - mape: 2.8677 - val_loss: 394.6740 - val_mape: 2.3458
# Epoch 47/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 432.0305 - mape: 2.4164 - val_loss: 369.6774 - val_mape: 2.1591
# Epoch 48/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 517.0417 - mape: 2.5825 - val_loss: 334.7069 - val_mape: 2.0954
# Epoch 49/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 405.6162 - mape: 2.2663 - val_loss: 394.6560 - val_mape: 2.3801
# Epoch 50/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 478.9223 - mape: 2.4502 - val_loss: 364.3880 - val_mape: 2.2061
# Epoch 51/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 430.3209 - mape: 2.3446 - val_loss: 383.4937 - val_mape: 2.1864
# Epoch 52/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 551.9219 - mape: 2.5817 - val_loss: 394.6012 - val_mape: 2.2089
# Epoch 53/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 463.8010 - mape: 2.4448 - val_loss: 354.7684 - val_mape: 2.2538
# Epoch 54/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 331.2869 - mape: 2.1866 - val_loss: 1232.2362 - val_mape: 4.2720
# Epoch 55/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 695.5423 - mape: 2.9854 - val_loss: 361.7518 - val_mape: 2.1815
# Epoch 56/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 461.5936 - mape: 2.5093 - val_loss: 1644.3943 - val_mape: 4.7757
# Epoch 57/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 692.8929 - mape: 2.7431 - val_loss: 358.5584 - val_mape: 2.1466
# Epoch 58/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 418.7421 - mape: 2.4099 - val_loss: 430.7519 - val_mape: 2.3010
# Epoch 59/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 542.6721 - mape: 2.6264 - val_loss: 798.1917 - val_mape: 3.5962
# Epoch 60/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 427.3870 - mape: 2.5638 - val_loss: 550.5326 - val_mape: 2.6351
# Epoch 61/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 544.8031 - mape: 2.7258 - val_loss: 326.5289 - val_mape: 2.0496
# Epoch 62/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 396.3895 - mape: 2.3308 - val_loss: 377.5539 - val_mape: 2.2369
# Epoch 63/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 407.7025 - mape: 2.2350 - val_loss: 647.6332 - val_mape: 2.9599
# Epoch 64/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 535.6803 - mape: 2.6079 - val_loss: 1208.2881 - val_mape: 4.1446
# Epoch 65/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 866.2959 - mape: 3.4720 - val_loss: 438.5552 - val_mape: 2.3065
# Epoch 66/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 409.4550 - mape: 2.2503 - val_loss: 479.3127 - val_mape: 2.4279
# Epoch 67/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 402.6122 - mape: 2.4179 - val_loss: 690.2628 - val_mape: 2.8663
# Epoch 68/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 646.5733 - mape: 2.7455 - val_loss: 911.3378 - val_mape: 3.5720
# Epoch 69/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 493.5497 - mape: 2.7827 - val_loss: 876.7675 - val_mape: 3.7642
# Epoch 70/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 425.0876 - mape: 2.4485 - val_loss: 907.8859 - val_mape: 3.5341
# Epoch 71/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 562.7023 - mape: 2.7579 - val_loss: 338.0376 - val_mape: 2.0966
# Epoch 72/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 396.2886 - mape: 2.4347 - val_loss: 443.2786 - val_mape: 2.2550
# Epoch 73/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 466.8322 - mape: 2.5128 - val_loss: 467.1226 - val_mape: 2.3523
# Epoch 74/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 389.9166 - mape: 2.3340 - val_loss: 702.5145 - val_mape: 3.3654
# Epoch 75/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 356.2951 - mape: 2.2512 - val_loss: 460.0663 - val_mape: 2.3438
# Epoch 76/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 364.6507 - mape: 2.2701 - val_loss: 401.8739 - val_mape: 2.1649
# Epoch 77/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 531.2598 - mape: 2.6091 - val_loss: 300.3090 - val_mape: 2.0881
# Epoch 78/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 540.4164 - mape: 2.8456 - val_loss: 481.5024 - val_mape: 2.7157
# Epoch 79/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 400.4699 - mape: 2.2463 - val_loss: 450.8308 - val_mape: 2.6849
# Epoch 80/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 365.3546 - mape: 2.2648 - val_loss: 298.5910 - val_mape: 1.9881
# Epoch 81/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 386.9704 - mape: 2.2903 - val_loss: 416.2316 - val_mape: 2.2027
# Epoch 82/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 398.4472 - mape: 2.3502 - val_loss: 292.4071 - val_mape: 1.9991
# Epoch 83/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 748.9364 - mape: 3.1547 - val_loss: 472.7807 - val_mape: 2.3078
# Epoch 84/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 398.1081 - mape: 2.3158 - val_loss: 1469.0657 - val_mape: 4.7239
# Epoch 85/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 501.5712 - mape: 2.6051 - val_loss: 1707.0352 - val_mape: 5.0505
# Epoch 86/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 712.4089 - mape: 3.1186 - val_loss: 409.7733 - val_mape: 2.2155
# Epoch 87/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 400.2891 - mape: 2.3158 - val_loss: 544.8475 - val_mape: 3.0011
# Epoch 88/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 576.2286 - mape: 2.8606 - val_loss: 585.6530 - val_mape: 2.5905
# Epoch 89/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 402.0673 - mape: 2.2570 - val_loss: 1796.5771 - val_mape: 5.3167
# Epoch 90/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 735.5815 - mape: 3.1812 - val_loss: 397.1919 - val_mape: 2.1848
# Epoch 91/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 323.1489 - mape: 2.2492 - val_loss: 364.3929 - val_mape: 2.0984
# Epoch 92/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 510.8693 - mape: 2.6370 - val_loss: 308.2655 - val_mape: 1.9634
# Epoch 93/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 266.1461 - mape: 1.9845 - val_loss: 323.3549 - val_mape: 2.1543
# Epoch 94/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 383.5843 - mape: 2.3596 - val_loss: 822.1729 - val_mape: 3.2974
# Epoch 95/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 610.0157 - mape: 2.9131 - val_loss: 534.4308 - val_mape: 2.5002
# Epoch 96/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 365.1676 - mape: 2.1946 - val_loss: 352.1776 - val_mape: 2.2142
# Epoch 97/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 359.8747 - mape: 2.2582 - val_loss: 345.3766 - val_mape: 2.2982
# Epoch 98/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 326.5676 - mape: 2.1403 - val_loss: 316.9665 - val_mape: 2.1019
# Epoch 99/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 344.2764 - mape: 2.2740 - val_loss: 327.0995 - val_mape: 2.1963
# Epoch 100/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 325.4490 - mape: 2.1657 - val_loss: 325.0185 - val_mape: 2.1862

# %%
test_pred=model.predict(test_data)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
model.save('model_best_titan124.keras')

# %%
#mae and accuracy for test data
def mae_accuracy_test(y_pred_close,act_data):

    mae_close = np.mean(abs(y_pred_close - act_data))

    return mae_close

# %%
act_data=act_data.reshape(len(act_data),1)

mae=mae_accuracy_test(test_pred,act_data)
print('mae_test=',mae)

#r2 score for test data
from sklearn.metrics import r2_score
r2=r2_score(act_data,test_pred)
print('r2_test=',r2)

#mape for test data
mape_=np.mean(np.abs((act_data - test_pred) / act_data)) * 100
print('mape_test=',mape_)

#accuracy for test data
acc_test=1-(mae/np.mean(act_data))
print("Accuracy_test=",acc_test)

#root mean square error for test data
from sklearn.metrics import mean_squared_error
rmse_test=np.sqrt(mean_squared_error(act_data,test_pred))
print('rmse_test=',rmse_test)
# Out:
# mae_test= 46.130944190087256
# r2_test= 0.9807207771058191
# mape_test= 1.8577470190324161
# Accuracy_test= 0.982019284076709
# rmse_test= 59.51797972273233

# %% [markdown]
# # Plot

# %%
#plot actual vs predicted for test data

plt.figure(figsize=(20,10))
plt.plot(act_data, color = 'black', label = 'Actual')
plt.plot(test_pred, color = 'green', label = 'Predicted')
plt.title('Actual vs Predicted')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %%
#plot epochs vs mape
plt.plot(history.history['mape'], label='mape')
plt.plot(history.history['val_mape'], label='val_mape')
plt.title('model mape')
plt.ylabel('mape')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
a=int(len(df))
b=int(0.8*(a-w))
y=b+w

df1=df['TITAN.NS(close)']
df_numpy=df1.to_numpy()
new_data=df_numpy[y-1:a-1]
new_data=new_data.reshape(len(new_data),1)

# %%
bs=test_pred-new_data
bs
#profit and loss    
def profit_loss(bs):
    n=len(bs)
    profit=0
    loss=0
    for i in range(n-1):
        if bs[i]>0:
            profit=profit+bs[i]
        else:
            loss=loss-bs[i]
    return profit,loss

profit,loss =profit_loss(bs)
profit_factor=profit/loss

print('profit=',profit)
print('loss=',loss)

print('profit=',profit-loss)
print('profit_factor=',profit_factor)
# Out:
# profit= [21024.76257324]
# loss= [2095.40234375]
# profit= [18929.36022949]
# profit_factor= [10.03375921]

# %%
signal=np.array([])

for i in range(len(bs)):
    if bs[i]>0:
        signal=np.append(signal,1)
    else:
        signal=np.append(signal,-1)

signal.reshape(len(signal),1)
df_out = df[['Date', 'TITAN.NS(close)']]
df_out_arr = df_out.to_numpy()
trading_signal = np.column_stack((df_out_arr[y:],signal))
trading_signal_df = pd.DataFrame(trading_signal, columns=['Date', 'Close Price', 'Trading Signal'])
trading_signal_df
# Out:
#            Date  Close Price Trading Signal
# 0    2021-07-06  1746.722656           -1.0
# 1    2021-07-07  1711.496948           -1.0
# 2    2021-07-08   1710.60498            1.0
# 3    2021-07-09  1704.907471            1.0
# 4    2021-07-12  1704.164307            1.0
# ..          ...          ...            ...
# 611  2023-12-22  3627.350098            1.0
# 612  2023-12-26  3656.699951            1.0
# 613  2023-12-27      3689.25            1.0
# 614  2023-12-28  3715.100098            1.0
# 615  2023-12-29  3675.449951            1.0
#
# [616 rows x 3 columns]

# %%
trading_signal_df['Date']=pd.to_datetime(trading_signal_df['Date'])
trading_signal_df['Close Price']=trading_signal_df['Close Price'].astype(float)
trading_signal_df['Trading Signal']=trading_signal_df['Trading Signal'].astype(float)

trading_signal_df.dtypes
# Out:
# Date              datetime64[ns]
# Close Price              float64
# Trading Signal           float64
# dtype: object

# %%
trading_signal_df.to_csv('/Users/vedantgupta/Documents/summer project/data-analysis-with-technical-indicators-2/final/trading_signals/titan124_nn_ts.csv',index=False)
